# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
from numpy.random import randint
from numpy.random import choice

# %%
from IPython.display import display, HTML, Image
html_str="<h2 style='color:pink;'>給你一張長輩圖,給你滿滿的愛</h2>"
egg=HTML(html_str)
display(egg)
a=Image('長輩圖1.jpg')
display(a)
# Out:
# <h2 style='color:pink;'>給你一張長輩圖,給你滿滿的愛</h2>
